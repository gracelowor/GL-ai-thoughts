# %% [markdown]
# <a href="https://colab.research.google.com/github/gracelowor/GL-ai-thoughts/blob/main/My_Thoughts_on_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Things I want to do
* Learn Python coding
* Learn Python for AI
* Be Gitty
